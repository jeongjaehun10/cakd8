# %% [markdown]
# # 정리

# %%
mutable - dict, list 수정가능한 
immutable - int, str, tuple, float 수정 불가한
import pandas as pd
df = pd.DataFrame({'v1':['1','2','1'],'v2':[5,3,2]})
from datetime import datetime
Dday=datetime(2023, 2, 24)
now =datetime.now()
Dday-now
df=pd.DataFrame([[1,4],[2,5],[3,6]], index=['a','b','c'] ,columns=['a','b'])
#인덱스에 문자 넣을 수 있다. 
df
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic' # 한글 처리하는 법 
exam.query('math>=50 & english >90') # 이게 맞음 따옴표 한개안에 
exam.query('math>=50 or english >90')
exam.query('math>=50' and 'english >90')
exam.query('class==1 and math >=50') # 왜 안될까?
class가 예약어라서 그런 것 같은데 
def class가 예약어라서 작동안함
df.query('sex=="F" and country =="Korea"')
#따옴표 구별 잘해줘야 함 
exam.sort_values(by ='math', ascending= False)# 수학 기준으로 정렬
exam['total'] =exam['math']+exam['english']+exam['science'] # 칼럼추가하기
exam.assign(total1=exam['math']+exam['english']+exam['science']) # 칼럼 추가하기
mpg.groupby(['drv', 'class']).apply(min) #일반적으로는 apply
pd.merge(test1, test2, how = 'left')
df.apply(np.mean)

# %%
정보.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 정보.describe()
#
# NameError: name '정보' is not defined

# %%
value_count는 한개의 칼럼에만 적용된다. o
#보통 시리즈에 대해서 하는데 데이터 프레임에도 함
# Out:
#   Input In [2]
#     value_count는 한개의 칼럼에만 적용된다. o
#                  ^
# SyntaxError: invalid syntax

# %%
mutable - dict, list 수정가능한 
immutable - int, str, tuple, float 수정 불가한
# Out:
#   Input In [3]
#     mutable - dict, list 수정가능한
#                          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.DataFrame({'v1':['1','2','1'],'v2':[5,3,2]})

# %%
import seaborn as sns

# %%
df.rename({'v1': 'V1', 'v2': 'V2'}, axis = 1)
# Out:
#   V1  V2
# 0  1   5
# 1  2   3
# 2  1   2

# %%
import datetime
Dday=datetime.datetime(2023, 2, 24)
now = datetime.datetime.now()
Dday-now
# Out:
# datetime.timedelta(days=155, seconds=52856, microseconds=969932)

# %%
from datetime import datetime
Dday=datetime(2023, 2, 24)
now =datetime.now()
Dday-now
# Out:
# datetime.timedelta(days=155, seconds=52740, microseconds=126987)

# %%
(Dday-now).days
# Out:
# 155

# %%
pd.DataFrame({'a':[1,2,3], 'b':[4,5,6]})
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.DataFrame([[1,4],[2,5],[3,6]],columns=['a','b'])
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df=pd.DataFrame([[1,4],[2,5],[3,6]], index=['a','b','c'] ,columns=['a','b'])
#인덱스에 문자 넣을 수 있다. 
df
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6

# %%
df= df.rename({'a':'A', 'b':'B'}, axis=1)# axis 안쓰면 안됨
df
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %%
exam.rename(columns={"english":"eng", "science": "sci"}, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 exam.rename(columns={"english":"eng", "science": "sci"}, inplace= True)
#
# NameError: name 'exam' is not defined

# %%
df['합']= df['A']+df['B']
df
# Out:
#    A  B  합
# a  1  4  5
# b  2  5  7
# c  3  6  9

# %%
iterable 객체에 대해 틀린것은? 
int 형 객체를 포함하지 않는다. 
tuple형 객체를 포함한다.
# Out:
#   Input In [28]
#     iterable 객체에 대해 틀린것은?
#              ^
# SyntaxError: invalid syntax

# %%
동적 타이핑의 한종류로 객체라 어떤 타입에 걸맞는 변수와 메소드를
지닌다면 간주하는 것은 
덕 타이핑
# Out:
#   Input In [29]
#     동적 타이핑의 한종류로 객체라 어떤 타입에 걸맞는 변수와 메소드를
#        ^
# SyntaxError: invalid syntax

# %%
df.describe() # 데이터 프레임 구조 알아봄
df.info() # 데이터 프레임 구조 알아봄
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   합       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
import numpy as np
arr = np.array(['A', 'B', 'A', 'C', 'B', 'D', 'E'])
data = np.random.randn(4, 7) # ran표준정규분포에서 뽐아냄

# %%
arr
# Out:
# array(['A', 'B', 'A', 'C', 'B', 'D', 'E'], dtype='<U1')

# %%
data
# Out:
# array([[-0.58675427, -0.2567908 , -0.7989735 , -0.52615951,  1.09336569,
#          1.72023845, -1.1648546 ],
#        [-0.54890677,  0.5267417 , -0.87763008,  0.52686121,  0.1976911 ,
#          0.6881146 , -1.97269467],
#        [-0.60372774, -0.3438575 , -1.86282446, -0.45952164,  0.87630556,
#          1.2364576 ,  1.60984535],
#        [ 0.16872808,  0.32082733, -1.30869074, -1.14886934,  1.04215963,
#         -0.17163003, -0.21708026]])

# %%
df = pd.read_excel("excel_exam.xlsx") 
df
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin'

# %%
df['평균'] = (df['math']+df['english']+df['science']) / 3

# %%
df['평균'].plot(kind="hist",rot=0)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns

# %%
df['합격여부'] = np.where(df['평균']>60, '합격', '불합격')
df
# Out:
#     id  class  math  english  science         평균 합격여부
# 0    1      1    50       98       50  66.000000   합격
# 1    2      1    60       97       60  72.333333   합격
# 2    3      1    45       86       78  69.666667   합격
# 3    4      1    30       98       58  62.000000   합격
# 4    5      2    25       80       65  56.666667  불합격
# 5    6      2    50       89       98  79.000000   합격
# 6    7      2    80       90       45  71.666667   합격
# 7    8      2    90       78       25  64.333333   합격
# 8    9      3    20       98       15  44.333333  불합격
# 9   10      3    50       98       45  64.333333   합격
# 10  11      3    65       65       65  65.000000   합격
# 11  12      3    45       85       32  54.000000  불합격
# 12  13      4    46       98       65  69.666667   합격
# 13  14      4    48       87       12  49.000000  불합격
# 14  15      4    75       56       78  69.666667   합격
# 15  16      4    58       98       65  73.666667   합격
# ...

# %%
sns.countplot(data=df, x='합격여부')
# Out:
# <AxesSubplot:xlabel='합격여부', ylabel='count'>

# %%
# 구글 ctrl 클릭하면 창안사라짐

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic' # 한글 처리하는 법

# %%
데이터 전처리 
데이터 가공 핸들링 랭글링 먼징
# Out:
#   Input In [55]
#     데이터 전처리
#         ^
# SyntaxError: invalid syntax

# %%
exam=pd.read_excel("excel_exam.xlsx")

# %%
exam['class']==1
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: class, dtype: bool

# %%
exam.query('math>50')# 행추출
# Out:
#     id  class  math  english  science
# 1    2      1    60       97       60
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam[exam['class']==1] # 거짓 참 안에 넣으면 됨 1반 찾기# 열 추출
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60
# 2   3      1    45       86       78
# 3   4      1    30       98       58

# %%
exam[exam['math']>=50]
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam[exam['math']>=50 & exam['class']==1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 exam[exam['math']>=50 & exam['class']==1]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
exam[ (exam['math']>=50) & (exam['class']==1)]
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
cond1= exam['class']==1
cond2=exam['math']>=50

# %%
exam[cond1& cond2]
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
cond = exam['math']>=50 & exam['class']==1
exam[cond]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 cond = exam['math']>=50 & exam['class']==1
#       2 exam[cond]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
exam.query('math>=50')
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.query('math>=50' & 'english >90')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 exam.query('math>=50' & 'english >90')
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %%
exam.query('math>=50' and 'english >90')
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 3    4      1    30       98       58
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 12  13      4    46       98       65
# 15  16      4    58       98       65

# %%
exam.query('math>=50 & english >90') # 이게 맞음 따옴표 한개안에
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 9   10      3    50       98       45
# 15  16      4    58       98       65

# %%
exam.query('math>=50 or english >90')
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 3    4      1    30       98       58
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 12  13      4    46       98       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.query('class==1 and math >=50') # 왜 안될까?
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [79] in <cell line: 1>
#     exam.query('class==1 and math >=50')
#
#   File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4111 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4240 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\eval.py:350 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:811 in __init__
#     self.terms = self.parse()
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:830 in parse
#     return self._visitor.visit(self.expr)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:411 in visit
# ...

# %%
class가 예약어라서 그런 것 같은데 
def class가 예약어라서 작동안함
# Out:
#   Input In [80]
#     class가 예약어라서 그런 것 같은데
#            ^
# SyntaxError: invalid syntax

# %%
exam =exam.rename({'class':'nclass'}, axis =1)

# %%
exam.rename({'class':'nclass'}, axis =1, inplace =True) # 인플레이스 해줘야 저장됨

# %%
exam.query('nclass==1 and math >=50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('nclass in [1,3,5]')

# [1,2,3,4,5] in [1,3,5]
1 in [1,3,5]
2 in [1,3,5]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df= pd.DataFrame({'sex':['F','M','F','M'], 'country':['Korea','China','Japen','USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japen
# 3   M     USA

# %%
df.query('sex=="F" and country =="Korea"')
#따옴표 구별 잘해줘야 함
# Out:
#   sex country
# 0   F   Korea

# %%
exam.iloc[:, 2:]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam.iloc[:, [2,3,4]]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam.loc[:, ['math','english','science']]#loc는 문자
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam[:2]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.drop(['id','nclass'], axis=1)
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
정렬 sort
sort_value
sort_index
# Out:
#   Input In [106]
#     정렬 sort
#        ^
# SyntaxError: invalid syntax

# %%
exam.sort_values('math', ascending= False)# 수학 기준으로 정렬
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values(by ='math', ascending= False)# 수학 기준으로 정렬
# Out:
#     id  class  math  english  science
# 7    8      2    90       78       25
# 18  19      5    89       68       87
# 17  18      5    80       78       90
# 6    7      2    80       90       45
# 19  20      5    78       83       58
# 14  15      4    75       56       78
# 16  17      5    65       68       98
# 10  11      3    65       65       65
# 1    2      1    60       97       60
# 15  16      4    58       98       65
# 9   10      3    50       98       45
# 5    6      2    50       89       98
# 0    1      1    50       98       50
# 13  14      4    48       87       12
# 12  13      4    46       98       65
# 11  12      3    45       85       32
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 8    9      3    20       98       15

# %%
exam.sort_values(by ='math', ascending= False)
# Out:
#     id  class  math  english  science
# 7    8      2    90       78       25
# 18  19      5    89       68       87
# 17  18      5    80       78       90
# 6    7      2    80       90       45
# 19  20      5    78       83       58
# 14  15      4    75       56       78
# 16  17      5    65       68       98
# 10  11      3    65       65       65
# 1    2      1    60       97       60
# 15  16      4    58       98       65
# 9   10      3    50       98       45
# 5    6      2    50       89       98
# 0    1      1    50       98       50
# 13  14      4    48       87       12
# 12  13      4    46       98       65
# 11  12      3    45       85       32
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 8    9      3    20       98       15

# %%
exam.sort_values(by =['math','english'], ascending= False)
# Out:
#     id  class  math  english  science
# 7    8      2    90       78       25
# 18  19      5    89       68       87
# 6    7      2    80       90       45
# 17  18      5    80       78       90
# 19  20      5    78       83       58
# 14  15      4    75       56       78
# 16  17      5    65       68       98
# 10  11      3    65       65       65
# 1    2      1    60       97       60
# 15  16      4    58       98       65
# 0    1      1    50       98       50
# 9   10      3    50       98       45
# 5    6      2    50       89       98
# 13  14      4    48       87       12
# 12  13      4    46       98       65
# 2    3      1    45       86       78
# 11  12      3    45       85       32
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 8    9      3    20       98       15

# %%
exam.sort_values(by =['class','math'], ascending= [True ,False])
# Out:
#     id  class  math  english  science
# 1    2      1    60       97       60
# 0    1      1    50       98       50
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 7    8      2    90       78       25
# 6    7      2    80       90       45
# 5    6      2    50       89       98
# 4    5      2    25       80       65
# 10  11      3    65       65       65
# 9   10      3    50       98       45
# 11  12      3    45       85       32
# 8    9      3    20       98       15
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 13  14      4    48       87       12
# 12  13      4    46       98       65
# 18  19      5    89       68       87
# 17  18      5    80       78       90
# 19  20      5    78       83       58
# 16  17      5    65       68       98

# %%
exam.sort_index() #인덱스 기준 정렬
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
assing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [229], in <cell line: 1>()
# ----> 1 assing
#
# NameError: name 'assing' is not defined

# %%
exam['total'] =exam['math']+exam['english']+exam['science'] # 칼럼추가하기
exam
# Out:
#     id  class  math  english  science  total
# 0    1      1    50       98       50    198
# 1    2      1    60       97       60    217
# 2    3      1    45       86       78    209
# 3    4      1    30       98       58    186
# 4    5      2    25       80       65    170
# 5    6      2    50       89       98    237
# 6    7      2    80       90       45    215
# 7    8      2    90       78       25    193
# 8    9      3    20       98       15    133
# 9   10      3    50       98       45    193
# 10  11      3    65       65       65    195
# 11  12      3    45       85       32    162
# 12  13      4    46       98       65    209
# 13  14      4    48       87       12    147
# 14  15      4    75       56       78    209
# 15  16      4    58       98       65    221
# 16  17      5    65       68       98    231
# 17  18      5    80       78       90    248
# 18  19      5    89       68       87    244
# 19  20      5    78       83       58    219

# %%
exam.assign(total1=exam['math']+exam['english']+exam['science']) # 칼럼 추가하기
# Out:
#     id  class  math  english  science  total  total1
# 0    1      1    50       98       50    198     198
# 1    2      1    60       97       60    217     217
# 2    3      1    45       86       78    209     209
# 3    4      1    30       98       58    186     186
# 4    5      2    25       80       65    170     170
# 5    6      2    50       89       98    237     237
# 6    7      2    80       90       45    215     215
# 7    8      2    90       78       25    193     193
# 8    9      3    20       98       15    133     133
# 9   10      3    50       98       45    193     193
# 10  11      3    65       65       65    195     195
# 11  12      3    45       85       32    162     162
# 12  13      4    46       98       65    209     209
# 13  14      4    48       87       12    147     147
# 14  15      4    75       56       78    209     209
# 15  16      4    58       98       65    221     221
# 16  17      5    65       68       98    231     231
# ...

# %%
#집단별 요약

# %%
exam.groupby('nclass')

# %%
list(exam.groupby('nclass'))
# Out:
# [(1,
#      id  nclass  math  english  science  total
#   0   1       1    50       98       50    198
#   1   2       1    60       97       60    217
#   2   3       1    45       86       78    209
#   3   4       1    30       98       58    186),
#  (2,
#      id  nclass  math  english  science  total
#   4   5       2    25       80       65    170
#   5   6       2    50       89       98    237
#   6   7       2    80       90       45    215
#   7   8       2    90       78       25    193),
#  (3,
#       id  nclass  math  english  science  total
#   8    9       3    20       98       15    133
#   9   10       3    50       98       45    193
#   10  11       3    65       65       65    195
#   11  12       3    45       85       32    162),
#  (4,
#       id  nclass  math  english  science  total
#   12  13       4    46       98       65    209
#   13  14       4    48       87       12    147
#   14  15       4    75       56       78    209
# ...

# %%
exam.groupby('nclass')[['math']]

# %%
exam.groupby('nclass').min() # 클래스별 합계 최소값
# Out:
#         id  math  english  science  total
# nclass
# 1        1    30       86       50    186
# 2        5    25       78       25    170
# 3        9    20       65       15    133
# 4       13    46       56       12    147
# 5       17    65       68       58    219

# %%
exam.groupby('nclass').min()[['math','science']]
# Out:
#         math  science
# nclass
# 1         30       50
# 2         25       25
# 3         20       15
# 4         46       12
# 5         65       58

# %%
exam[['nclass' ,'math','science']].groupby('nclass')

# %%
exam[['nclass' ,'math','science']].groupby('nclass').min()
# Out:
#         math  science
# nclass
# 1         30       50
# 2         25       25
# 3         20       15
# 4         46       12
# 5         65       58

# %%
import pydataset

# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
mpg=pydataset.data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.groupby(['drv', 'class']).min()['cty']
# Out:
#                 cty
# drv class
# 4   compact      15
#     midsize      15
#     pickup        9
#     subcompact   19
#     suv           9
# f   compact      16
#     midsize      16
#     minivan      11
#     subcompact   16
# r   2seater      15
#     subcompact   14
#     suv          11

# %%
mpg.groupby(['drv', 'class']).agg(min)[['cty']] # group by에서는 이거 씀 집단별 요약
# Out:
#                 cty
# drv class
# 4   compact      15
#     midsize      15
#     pickup        9
#     subcompact   19
#     suv           9
# f   compact      16
#     midsize      16
#     minivan      11
#     subcompact   16
# r   2seater      15
#     subcompact   14
#     suv          11

# %%
mpg.groupby(['drv', 'class']).apply(min) #일반적으로는 apply
# Out:
#                manufacturer               model  displ  year  cyl     trans  \
# drv class
# 4   compact            audi          a4 quattro    1.8  1999    4  auto(l5)
#     midsize            audi          a6 quattro    2.8  1999    6  auto(l5)
#     pickup            dodge   dakota pickup 4wd    2.7  1999    4  auto(l4)
#     subcompact       subaru         impreza awd    2.2  1999    4  auto(l4)
#     suv           chevrolet         4runner 4wd    2.5  1999    4  auto(l4)
# f   compact            audi                  a4    1.8  1999    4  auto(av)
#     midsize       chevrolet              altima    1.8  1999    4  auto(av)
#     minivan           dodge         caravan 2wd    2.4  1999    4  auto(l3)
#     subcompact        honda               civic    1.6  1999    4  auto(l4)
# r   2seater       chevrolet            corvette    5.7  1999    8  auto(l4)
#     subcompact         ford             mustang    3.8  1999    6  auto(l4)
# ...

# %%
mpg.groupby(['drv', 'class']).agg([min, max]) # group by에서는 이거 씀
# Out:
#                manufacturer                           model  \
#                         min         max                 min
# drv class
# 4   compact            audi      subaru          a4 quattro
#     midsize            audi        audi          a6 quattro
#     pickup            dodge      toyota   dakota pickup 4wd
#     subcompact       subaru      subaru         impreza awd
#     suv           chevrolet      toyota         4runner 4wd
# f   compact            audi  volkswagen                  a4
#     midsize       chevrolet  volkswagen              altima
#     minivan           dodge       dodge         caravan 2wd
#     subcompact        honda  volkswagen               civic
# r   2seater       chevrolet   chevrolet            corvette
#     subcompact         ford        ford             mustang
#     suv           chevrolet     lincoln  c1500 suburban 2wd
#
#                                   displ       year       cyl         trans  \
# ...

# %%
mpg.groupby(['drv', 'class']).agg([min, max])[['cty']] # 두개 알수 있음 칼럼마다 다른 함수 적용 시킬때
# Out:
#                cty
#                min max
# drv class
# 4   compact     15  20
#     midsize     15  17
#     pickup       9  17
#     subcompact  19  21
#     suv          9  20
# f   compact     16  33
#     midsize     16  23
#     minivan     11  18
#     subcompact  16  35
# r   2seater     15  16
#     subcompact  14  18
#     suv         11  14

# %%
mpg.groupby(['drv', 'class']).agg({'cty':min, 'hwy':max})
# Out:
#                 cty  hwy
# drv class
# 4   compact      15   28
#     midsize      15   25
#     pickup        9   22
#     subcompact   19   26
#     suv           9   27
# f   compact      16   44
#     midsize      16   32
#     minivan      11   24
#     subcompact   16   44
# r   2seater      15   26
#     subcompact   14   26
#     suv          11   20

# %%
mpg.groupby(['drv', 'class']).agg(mean_cty=('cty','mean'))
# Out:
#                  mean_cty
# drv class
# 4   compact     18.000000
#     midsize     16.000000
#     pickup      13.000000
#     subcompact  19.500000
#     suv         13.823529
# f   compact     20.857143
#     midsize     18.973684
#     minivan     15.818182
#     subcompact  22.363636
# r   2seater     15.400000
#     subcompact  15.888889
#     suv         12.000000

# %%
test1 =pd.DataFrame({'id':[1,2,3,4,5], 'midterm':[60,80,70,90,85]})
test2 =pd.DataFrame({'id':[1,2,3,4,5], 'final':[70,83,65,95,80]})
# 데이터 프레임 합치기 merge concat

# %%
pd.merge(test1, test2) # how inner 공통된거 찾아서 합 디폴트 값
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
test1 =pd.DataFrame({'id':[1,2,3,4,5], 'midterm':[60,80,70,90,85]})
test2 =pd.DataFrame({'id':[1,2,3,6,7], 'final':[70,83,65,95,80]})

# %%
pd.merge(test1, test2) # 공통된것만
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65

# %%
pd.merge(test1, test2, how = 'outer')
# Out:
#    id  midterm  final
# 0   1     60.0   70.0
# 1   2     80.0   83.0
# 2   3     70.0   65.0
# 3   4     90.0    NaN
# 4   5     85.0    NaN
# 5   6      NaN   95.0
# 6   7      NaN   80.0

# %%
pd.merge(test1, test2, how = 'left')
# Out:
#    id  midterm  final
# 0   1       60   70.0
# 1   2       80   83.0
# 2   3       70   65.0
# 3   4       90    NaN
# 4   5       85    NaN

# %%
pd.merge(test1, test2, how = 'right')
# Out:
#    id  midterm  final
# 0   1     60.0     70
# 1   2     80.0     83
# 2   3     70.0     65
# 3   6      NaN     95
# 4   7      NaN     80

# %%
exam.drop('total', axis = 1, inplace=True)

# %%
teacher= pd.DataFrame({'nclass':[1,2,3,4,5],'teacher':["choi",'park','hong',"kim", "jeong"]})

# %%
pd.merge(exam,teacher)
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50    choi
# 1    2       1    60       97       60    choi
# 2    3       1    45       86       78    choi
# 3    4       1    30       98       58    choi
# 4    5       2    25       80       65    park
# 5    6       2    50       89       98    park
# 6    7       2    80       90       45    park
# 7    8       2    90       78       25    park
# 8    9       3    20       98       15    hong
# 9   10       3    50       98       45    hong
# 10  11       3    65       65       65    hong
# 11  12       3    45       85       32    hong
# 12  13       4    46       98       65     kim
# 13  14       4    48       87       12     kim
# 14  15       4    75       56       78     kim
# 15  16       4    58       98       65     kim
# 16  17       5    65       68       98   jeong
# 17  18       5    80       78       90   jeong
# 18  19       5    89       68       87   jeong
# ...

# %%
pd.merge(exam,teacher, on='nclass')
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50    choi
# 1    2       1    60       97       60    choi
# 2    3       1    45       86       78    choi
# 3    4       1    30       98       58    choi
# 4    5       2    25       80       65    park
# 5    6       2    50       89       98    park
# 6    7       2    80       90       45    park
# 7    8       2    90       78       25    park
# 8    9       3    20       98       15    hong
# 9   10       3    50       98       45    hong
# 10  11       3    65       65       65    hong
# 11  12       3    45       85       32    hong
# 12  13       4    46       98       65     kim
# 13  14       4    48       87       12     kim
# 14  15       4    75       56       78     kim
# 15  16       4    58       98       65     kim
# 16  17       5    65       68       98   jeong
# 17  18       5    80       78       90   jeong
# 18  19       5    89       68       87   jeong
# ...

# %%
concat 뭐가 공통인지 상관 x 걍 붙임
# Out:
#   Input In [166]
#     concat 뭐가 공통인지 상관 x 걍 붙임
#            ^
# SyntaxError: invalid syntax

# %%
pd.concat([test1, test2]) # NaN 결측치 값
# Out:
#    id  midterm  final
# 0   1     60.0    NaN
# 1   2     80.0    NaN
# 2   3     70.0    NaN
# 3   4     90.0    NaN
# 4   5     85.0    NaN
# 0   1      NaN   70.0
# 1   2      NaN   83.0
# 2   3      NaN   65.0
# 3   6      NaN   95.0
# 4   7      NaN   80.0

# %%
pd.concat([test1, test2], axis =1)# 원래 세로 합치기인데 가로 합치기 처럼 됨
# Out:
#    id  midterm  id  final
# 0   1       60   1     70
# 1   2       80   2     83
# 2   3       70   3     65
# 3   4       90   6     95
# 4   5       85   7     80

# %%
pd.concat([test1, test2], axis =1, join ='inner')# 원래 세로 합치기인데 가로 합치기 처럼 됨
# Out:
#    id  midterm  id  final
# 0   1       60   1     70
# 1   2       80   2     83
# 2   3       70   3     65
# 3   4       90   6     95
# 4   5       85   7     80

# %%
test2.reindex([3,4,5,6,7])# 인덱스 바꾸기
# Out:
#     id  final
# 3  6.0   95.0
# 4  7.0   80.0
# 5  NaN    NaN
# 6  NaN    NaN
# 7  NaN    NaN

# %%
인덱스 바꾸기 
reindex 
set_index
reset_index
# Out:
#   Input In [174]
#     인덱스 바꾸기
#         ^
# SyntaxError: invalid syntax

# %%
test3 =test2.rename({'final':'midterm'}, axis=1)

# %%
test3
# Out:
#    id  midterm
# 0   1       70
# 1   2       83
# 2   3       65
# 3   6       95
# 4   7       80

# %%
group = pd.concat([test1,test3])

# %%
list(group.groupby('id'))
# Out:
# [(1,
#      id  midterm
#   0   1       60
#   0   1       70),
#  (2,
#      id  midterm
#   1   2       80
#   1   2       83),
#  (3,
#      id  midterm
#   2   3       70
#   2   3       65),
#  (4,
#      id  midterm
#   3   4       90),
#  (5,
#      id  midterm
#   4   5       85),
#  (6,
#      id  midterm
#   3   6       95),
#  (7,
#      id  midterm
#   4   7       80)]

# %%
group.groupby('id').mean()['midterm']#그러나 메소드 형식으로 .mean은 가능하다.
# Out:
# id
# 1    65.0
# 2    81.5
# 3    67.5
# 4    90.0
# 5    85.0
# 6    95.0
# 7    80.0
# Name: midterm, dtype: float64

# %%
프로그램에서 저장되는 모든 데이터는 객체임 
메소드란 클래스안에 있는 함수를 말함

# %%
group.groupby('id').agg(np.mean)# mean은 내장함수가 없어서 np.mean이다.
# Out:
#     midterm
# id
# 1      65.0
# 2      81.5
# 3      67.5
# 4      90.0
# 5      85.0
# 6      95.0
# 7      80.0

# %%
mpg.groupby(['drv']).min()[['cty']] # cty가 열이 한개지만 열 두개로 처리할려고 가로 두개
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
mpg[['drv','cty']].groupby(['drv']).min()
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
mpg.groupby(['drv'])[['cty']].min()
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
# value count는 보통 series에 씀

# %% [markdown]
# # 결측치

# %%
exam.iloc[0,2] =np.nan
exam.iloc[2,4] =np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1   NaN     98.0     50.0
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
#결측치 확인하기 
df= exam.copy()
pd.isna(df)
# Out:
#        id  nclass   math  english  science
# 0   False   False   True    False    False
# 1   False   False  False     True    False
# 2   False   False  False    False     True
# 3   False   False  False    False    False
# 4   False   False  False    False    False
# 5   False   False  False    False    False
# 6   False   False  False    False    False
# 7   False   False  False    False    False
# 8   False   False  False    False    False
# 9   False   False  False    False    False
# 10  False   False  False    False    False
# 11  False   False  False    False    False
# 12  False   False  False    False    False
# 13  False   False  False    False    False
# 14  False   False  False    False    False
# 15  False   False  False    False    False
# 16  False   False  False    False    False
# 17  False   False  False    False    False
# 18  False   False  False    False    False
# 19  False   False  False    False    False

# %%
pd.isna(df).sum() #빈도수 확인
# Out:
# id         0
# nclass     0
# math       1
# english    1
# science    1
# dtype: int64

# %%
#결측치 제거하기 
df.dropna() # 인덱스 번호가 0번부터 시작하지 않는 문제가 발생
# Out:
#     id  nclass  math  english  science
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df.dropna(subset='math') # subset부분집합이니 부분만
# Out:
#     id  nclass  math  english  science
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df['math'].mean() # 판다스에서는  결측치 있어도 계산함 
#R에서는 na.rm=T 해주면 됨
# Out:
# 57.8421052631579

# %%
np.mean(df.math)
# Out:
# 57.8421052631579

# %%
df.apply(np.mean)
# Out:
# id         10.500000
# nclass      3.000000
# math       57.842105
# english    84.263158
# science    58.473684
# dtype: float64

# %%
#결측치 대체하기 
m=df['math'].mean()
m
# Out:
# 57.8421052631579

# %%
df['math']=df['math'].fillna(m)

# %%
df['english'].fillna(method='ffill')
df['english'].fillna(method='bfill', inplace= True)

# %%
df['science'].fillna(np.mean(df.science), inplace=True)

# %% [markdown]
# # 이상치
# - 이상치 존재

# %%
df.iloc[0,2]=10
df.iloc[1,3]=10
df
# Out:
#     id  nclass  math  english    science
# 0    1       1  10.0     98.0  50.000000
# 1    2       1  60.0     10.0  60.000000
# 2    3       1  45.0     86.0  58.473684
# 3    4       1  30.0     98.0  58.000000
# 4    5       2  25.0     80.0  65.000000
# 5    6       2  50.0     89.0  98.000000
# 6    7       2  80.0     90.0  45.000000
# 7    8       2  90.0     78.0  25.000000
# 8    9       3  20.0     98.0  15.000000
# 9   10       3  50.0     98.0  45.000000
# 10  11       3  65.0     65.0  65.000000
# 11  12       3  45.0     85.0  32.000000
# 12  13       4  46.0     98.0  65.000000
# 13  14       4  48.0     87.0  12.000000
# 14  15       4  75.0     56.0  78.000000
# 15  16       4  58.0     98.0  65.000000
# 16  17       5  65.0     68.0  98.000000
# 17  18       5  80.0     78.0  90.000000
# 18  19       5  89.0     68.0  87.000000
# 19  20       5  78.0     83.0  58.000000

# %%
sns.boxplot(data=df, y='math')
# Out:
# <AxesSubplot:ylabel='math'>

# %%
df.iloc[0,2]=np.nan
df.iloc[1,3]=10

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg=pydataset.data('mpg')
mpg.query('model=="a4"').assign(total=(mpg['hwy']+mpg['cty'])).groupby('year').agg(mean_tot =('total','mean'))
# Out:
#       mean_tot
# year
# 1999     45.75
# 2008     49.00

# %%
exam=pd.read_excel("excel_exam.xlsx")
exam.rename({'class':'nclass'}, axis =1, inplace =True)
exam.groupby('nclass').agg(mean_math=('math', 'mean'), mean_sum=('math','sum'))
# Out:
#         mean_math  mean_sum
# nclass
# 1           46.25       185
# 2           61.25       245
# 3           45.00       180
# 4           56.75       227
# 5           78.00       312

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58
