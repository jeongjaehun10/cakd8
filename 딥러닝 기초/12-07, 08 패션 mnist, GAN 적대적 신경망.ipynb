# %%
import pandas as pd
import pydataset

# %%
mpg = pydataset.data('mpg')
mpg[:2]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
mpg.rename({'fl': 'fuel'}, axis=1, inplace=True)

# %%
mpg[mpg['manufacturer'].str.contains('s')]
# Out:
#     manufacturer           model  displ  year  cyl       trans drv  cty  hwy  \
# 142       nissan          altima    2.4  1999    4  manual(m5)   f   21   29
# 143       nissan          altima    2.4  1999    4    auto(l4)   f   19   27
# 144       nissan          altima    2.5  2008    4    auto(av)   f   23   31
# 145       nissan          altima    2.5  2008    4  manual(m6)   f   23   32
# 146       nissan          altima    3.5  2008    6  manual(m6)   f   19   27
# 147       nissan          altima    3.5  2008    6    auto(av)   f   19   26
# 148       nissan          maxima    3.0  1999    6    auto(l4)   f   18   26
# 149       nissan          maxima    3.0  1999    6  manual(m5)   f   19   25
# 150       nissan          maxima    3.5  2008    6    auto(av)   f   19   25
# 151       nissan  pathfinder 4wd    3.3  1999    6    auto(l4)   4   14   17
# 152       nissan  pathfinder 4wd    3.3  1999    6  manual(m5)   4   15   17
# ...

# %%
mpg.query("fuel in ['p', 'r', 'e']")
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg[mpg['fuel'].isin(['p', 'r', 'e'])]
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg.groupby(['manufacturer', 'year']).mean()[['cty']]
# Out:
#                          cty
# manufacturer year
# audi         1999  17.111111
#              2008  18.111111
# chevrolet    1999  15.142857
#              2008  14.916667
# dodge        1999  13.375000
#              2008  12.952381
# ford         1999  13.933333
#              2008  14.100000
# honda        1999  24.800000
#              2008  24.000000
# hyundai      1999  18.333333
#              2008  18.875000
# jeep         1999  14.500000
#              2008  13.166667
# land rover   1999  11.000000
#              2008  12.000000
# lincoln      1999  11.000000
#              2008  12.000000
# mercury      1999  13.500000
#              2008  13.000000
# nissan       1999  17.666667
#              2008  18.428571
# pontiac      1999  17.000000
#              2008  17.000000
# subaru       1999  19.000000
#              2008  19.500000
# toyota       1999  18.150000
#              2008  19.071429
# volkswagen   1999  21.250000
#              2008  20.454545

# %%
import numpy as np

# %%
mpg.groupby(['manufacturer', 'year']).agg({'cty': 'mean', 'hwy': 'max'}) 
mpg.groupby(['manufacturer', 'year']).agg({'cty' :np.mean, 'hwy': np.max })
# Out:
#                          cty  hwy
# manufacturer year
# audi         1999  17.111111   29
#              2008  18.111111   31
# chevrolet    1999  15.142857   27
#              2008  14.916667   30
# dodge        1999  13.375000   24
#              2008  12.952381   24
# ford         1999  13.933333   26
#              2008  14.100000   26
# honda        1999  24.800000   33
#              2008  24.000000   36
# hyundai      1999  18.333333   29
#              2008  18.875000   31
# jeep         1999  14.500000   20
#              2008  13.166667   22
# land rover   1999  11.000000   15
#              2008  12.000000   18
# lincoln      1999  11.000000   17
#              2008  12.000000   18
# mercury      1999  13.500000   17
#              2008  13.000000   19
# nissan       1999  17.666667   29
#              2008  18.428571   32
# pontiac      1999  17.000000   27
#              2008  17.000000   28
# subaru       1999  19.000000   26
#              2008  19.500000   27
# ...

# %%
mpg.pivot_table(index='manufacturer', columns='model', values='cty')
# Out:
# model         4runner 4wd         a4  a4 quattro  a6 quattro     altima  \
# manufacturer
# audi                  NaN  18.857143      17.125        16.0        NaN
# chevrolet             NaN        NaN         NaN         NaN        NaN
# dodge                 NaN        NaN         NaN         NaN        NaN
# ford                  NaN        NaN         NaN         NaN        NaN
# honda                 NaN        NaN         NaN         NaN        NaN
# hyundai               NaN        NaN         NaN         NaN        NaN
# jeep                  NaN        NaN         NaN         NaN        NaN
# land rover            NaN        NaN         NaN         NaN        NaN
# lincoln               NaN        NaN         NaN         NaN        NaN
# mercury               NaN        NaN         NaN         NaN        NaN
# nissan                NaN        NaN         NaN         NaN  20.666667
# pontiac               NaN        NaN         NaN         NaN        NaN
# ...

# %%
mpg_1=mpg.sample(frac=0.5, random_state=1111) #frac 분수 = 비율

# %%
# mpg에서 mpg_1을 뺀다.
mpg.drop(mpg_1.index, axis=0)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# ...

# %%
mpg[~mpg.isin(mpg_1).any(axis=1)]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# ...

# %%
mpg[mpg.index.isin(mpg_1.index) == False]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# ...

# %%
mpg[~mpg.index.isin(mpg_1.index)]  # ~ fasle인것만 고른다.
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# ...

# %%
mpg.isin(mpg_1)
# Out:
#      manufacturer  model  displ   year    cyl  trans    drv    cty    hwy  \
# 1           False  False  False  False  False  False  False  False  False
# 2            True   True   True   True   True   True   True   True   True
# 3           False  False  False  False  False  False  False  False  False
# 4            True   True   True   True   True   True   True   True   True
# 5            True   True   True   True   True   True   True   True   True
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 230         False  False  False  False  False  False  False  False  False
# 231         False  False  False  False  False  False  False  False  False
# 232         False  False  False  False  False  False  False  False  False
# 233         False  False  False  False  False  False  False  False  False
# 234          True   True   True   True   True   True   True   True   True
#
#       fuel  class   info
# 1    False  False  False
# 2     True   True  False
# ...

# %%
mpg.isin(mpg_1).any(axis=1) # 행을 가져다가 쓴거임
# Out:
# 1      False
# 2       True
# 3      False
# 4       True
# 5       True
#        ...
# 230    False
# 231    False
# 232    False
# 233    False
# 234     True
# Length: 234, dtype: bool

# %%
mpg.index.isin(mpg_1.index).all()
# Out:
# False

# %%
mpg.index.isin(mpg_1.index) # 들어가 있는 것은 True니까 없는 것은 False이다.
# Out:
# array([False,  True, False,  True,  True,  True, False,  True, False,
#        False,  True, False,  True,  True, False, False,  True,  True,
#        False,  True, False, False, False, False, False, False, False,
#         True, False, False, False,  True, False,  True,  True,  True,
#         True,  True,  True,  True, False,  True, False, False, False,
#        False,  True, False, False,  True,  True,  True, False,  True,
#        False, False,  True,  True,  True,  True, False, False,  True,
#         True, False, False,  True, False,  True, False,  True, False,
#         True, False, False,  True, False, False,  True,  True,  True,
#        False,  True,  True,  True,  True, False,  True, False, False,
#         True, False,  True, False,  True,  True,  True,  True,  True,
#        False,  True, False, False,  True,  True, False,  True, False,
#        False, False,  True,  True, False,  True,  True,  True, False,
# ...

# %%
mpg['info']= mpg['manufacturer'].values+' ' +mpg['model'].values+' ' +mpg['drv'].values
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class                 info
# 1    compact            audi a4 f
# ...

# %%
manuf = mpg.manufacturer.values
model = mpg.model.values
drv = mpg.drv.values

info = list(zip(manuf, model, drv))

mpg['info'] = info
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class                     info
# 1    compact            (audi, a4, f)
# ...

# %%
mpg['info']=mpg.apply(lambda x : x.manufacturer+'/'+x.model+'/'+x.drv,axis = 1) 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class                 info
# 1    compact            audi/a4/f
# ...

# %%
mpg['info'] = mpg['manufacturer'] + '/' + mpg['model'] + '/' + mpg['drv'] 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class                 info
# 1    compact            audi/a4/f
# ...

# %%
mpg1 = mpg.sample(n=100, random_state=1234)
mpg1[:2]
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  cty  hwy fl  \
# 105        honda  civic    1.8  2008    4  manual(m5)   f   26   34  r
# 209   volkswagen    gti    2.0  1999    4    auto(l4)   f   19   26  r
#
#           class
# 105  subcompact
# 209     compact

# %%
mpg2= mpg.drop(index= mpg1.index, axis=0)
mpg2 = mpg[~mpg.index.isin(mpg1.index)]

# %%
pd.concat([mpg1, mpg2], ignore_index=True) # 공통되게 있음
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 0          honda              civic    1.8  2008    4  manual(m5)   f   26
# 1     volkswagen                gti    2.0  1999    4    auto(l4)   f   19
# 2           audi                 a4    3.1  2008    6    auto(av)   f   18
# 3        hyundai             sonata    2.4  2008    4  manual(m5)   f   21
# 4          dodge  dakota pickup 4wd    3.9  1999    6  manual(m5)   4   14
# ..           ...                ...    ...   ...  ...         ...  ..  ...
# 229   volkswagen             passat    1.8  1999    4  manual(m5)   f   21
# 230   volkswagen             passat    1.8  1999    4    auto(l5)   f   18
# 231   volkswagen             passat    2.0  2008    4    auto(s6)   f   19
# 232   volkswagen             passat    2.8  1999    6    auto(l5)   f   16
# 233   volkswagen             passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl       class
# 0     34  r  subcompact
# ...

# %%
# 겹치는 부분 빼고 하기 
mpg3= mpg.sample(frac=0.7, random_state=1234) 
mpg4 = pd.concat([mpg1, mpg3], ignore_index=True).drop_duplicates()
mpg4
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 0          honda                   civic    1.8  2008    4  manual(m5)   f
# 1     volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 2           audi                      a4    3.1  2008    6    auto(av)   f
# 3        hyundai                  sonata    2.4  2008    4  manual(m5)   f
# 4          dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 5     volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 6      chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 7           ford                 mustang    4.0  2008    6  manual(m5)   r
# 8           audi                      a4    2.8  1999    6  manual(m5)   f
# 9     land rover             range rover    4.0  1999    8    auto(l4)   4
# 10       hyundai                  sonata    2.4  2008    4    auto(l4)   f
# ...

# %%
pd.merge(mpg1, mpg3, how="outer")
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 0          honda                   civic    1.8  2008    4  manual(m5)   f
# 1     volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 2           audi                      a4    3.1  2008    6    auto(av)   f
# 3        hyundai                  sonata    2.4  2008    4  manual(m5)   f
# 4          dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 5     volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 6      chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 7           ford                 mustang    4.0  2008    6  manual(m5)   r
# 8           audi                      a4    2.8  1999    6  manual(m5)   f
# 9     land rover             range rover    4.0  1999    8    auto(l4)   4
# 10       hyundai                  sonata    2.4  2008    4    auto(l4)   f
# ...

# %%
mpg_1 = mpg[:5]
mpg_3 = mpg[3:7]
pd.merge(mpg_1 , mpg_3, how='outer') # 중복되는 것 없이 합집합
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
# 5         audi    a4    2.8  1999    6  manual(m5)   f   18   26  p  compact
# 6         audi    a4    3.1  2008    6    auto(av)   f   18   27  p  compact

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg['info']= mpg['manufacturer'].values+'/' +mpg['model'].values+'/' +mpg['drv'].values

# %%
mpg.drop(['manufacturer', 'model','drv'], axis=1, inplace=True)

# %%
a=[]
for i in range(1):
    i= mpg['info'].str.split('/')
    a.append(i)
a
# Out:
# [1                [audi, a4, f]
#  2                [audi, a4, f]
#  3                [audi, a4, f]
#  4                [audi, a4, f]
#  5                [audi, a4, f]
#                  ...
#  230    [volkswagen, passat, f]
#  231    [volkswagen, passat, f]
#  232    [volkswagen, passat, f]
#  233    [volkswagen, passat, f]
#  234    [volkswagen, passat, f]
#  Name: info, Length: 234, dtype: object]

# %%
for i in mpg['info']:
    a=i.split('/')[0]
    b=i.split('/')[1]
    c=i.split('/')[2]
    mpg['manufacturer']=a
    mpg['model']=b
    mpg['drv']= c
    
mpg
# Out:
#      displ  year  cyl       trans  cty  hwy fl    class                 info  \
# 1      1.8  1999    4    auto(l5)   18   29  p  compact            audi/a4/f
# 2      1.8  1999    4  manual(m5)   21   29  p  compact            audi/a4/f
# 3      2.0  2008    4  manual(m6)   20   31  p  compact            audi/a4/f
# 4      2.0  2008    4    auto(av)   21   30  p  compact            audi/a4/f
# 5      2.8  1999    6    auto(l5)   16   26  p  compact            audi/a4/f
# ..     ...   ...  ...         ...  ...  ... ..      ...                  ...
# 230    2.0  2008    4    auto(s6)   19   28  p  midsize  volkswagen/passat/f
# 231    2.0  2008    4  manual(m6)   21   29  p  midsize  volkswagen/passat/f
# 232    2.8  1999    6    auto(l5)   16   26  p  midsize  volkswagen/passat/f
# 233    2.8  1999    6  manual(m5)   18   26  p  midsize  volkswagen/passat/f
# 234    3.6  2008    6    auto(s6)   17   26  p  midsize  volkswagen/passat/f
#
#     manufacturer   model drv
# ...

# %%
for i in range(1,3):
    mpg['manufacturer']=mpg['info'].str.split('/')[i][0]
    mpg['model']=mpg['info'].str.split('/')[i][1]
    mpg['drv']=mpg['info'].str.split('/')[i][2]

# %%
slice_1=mpg['info'].str.split('/')
mpg['manufacturer']=slice_1.str.get(0)
mpg['model']=slice_1.str.get(1)
mpg['drv']=slice_1.str.get(2)

# %%
for i, [a,b,c] in enumerate(mpg['info'].str.split('/')):
    mpg['manufacturer'][i]=a
    mpg['model'][i]=b
    mpg['drv'][i]=c

# %%
mpg['info'].str.split('/', expand=True)
# Out:
#               0       1  2
# 1          audi      a4  f
# 2          audi      a4  f
# 3          audi      a4  f
# 4          audi      a4  f
# 5          audi      a4  f
# ..          ...     ... ..
# 230  volkswagen  passat  f
# 231  volkswagen  passat  f
# 232  volkswagen  passat  f
# 233  volkswagen  passat  f
# 234  volkswagen  passat  f
#
# [234 rows x 3 columns]

# %%
info_split = mpg['info'].str.split('/')
mpg['manufacturer'] = [x[0] for x in info_split]
mpg['model'] = [x[1] for x in info_split]
mpg['drv'] = [x[2] for x in info_split]
mpg

# %%
mpg[mpg['trans'].str.contains('manual')]
# Out:
#      displ  year  cyl       trans  cty  hwy fl       class  \
# 2      1.8  1999    4  manual(m5)   21   29  p     compact
# 3      2.0  2008    4  manual(m6)   20   31  p     compact
# 6      2.8  1999    6  manual(m5)   18   26  p     compact
# 8      1.8  1999    4  manual(m5)   18   26  p     compact
# 10     2.0  2008    4  manual(m6)   20   28  p     compact
# 13     2.8  1999    6  manual(m5)   17   25  p     compact
# 15     3.1  2008    6  manual(m6)   15   25  p     compact
# 24     5.7  1999    8  manual(m6)   16   26  p     2seater
# 26     6.2  2008    8  manual(m6)   16   26  p     2seater
# 28     7.0  2008    8  manual(m6)   15   24  p     2seater
# 49     3.7  2008    6  manual(m6)   15   19  r      pickup
# 52     3.9  1999    6  manual(m5)   14   17  r      pickup
# 56     5.2  1999    8  manual(m5)   11   17  r      pickup
# 65     4.7  2008    8  manual(m6)   12   16  r      pickup
# 69     4.7  2008    8  manual(m6)   12   16  r      pickup
# ...

# %% [markdown]
# # CNN을 사용하여, fashion mnist를 분류하여 test_set_accuracy를 찾아 봅시다.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_images, train_labels),(test_images, test_labels) = fashion_mnist.load_data()

# %%
plt.imshow(train_images[0], cmap="gray");

# %%
len(train_images)
# Out:
# 60000

# %%
#데이터 증식
data_augmentation =keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %%
### 모델 훈련하기
history = model.fit(partial_x_train,
                   partial_y_train,
                   epochs = 20,
                   batch_size = 512,
                   validation_data = (x_val, y_val))

# %%
(train_images, train_labels),(test_images, test_labels) = fashion_mnist.load_data()
train_images=train_images.reshape(60000, 28,28,1) 
train_images=train_images/255.0
test_images=test_images.reshape(10000, 28,28,1) 
test_images=test_images/255.0     

x_val = train_images[:15000]
x_train = train_images[15000:]

y_val = train_labels[:15000]
y_train = train_labels[15000:]

inputs = keras.Input(shape=(28, 28, 1)) # 흑백은 1이다. 

x =Conv2D(filters=32, kernel_size=(3,3), activation="relu")(inputs) # input이 1개라서 그럼  64*10+ 64
x= MaxPooling2D(pool_size=(2, 2))(x)
x =Conv2D(filters=64, kernel_size=(3,3), activation="relu")(x) # input이 1개라서 그럼  64*10+ 64
x= MaxPooling2D(pool_size=(2, 2))(x)
x =Conv2D(filters=128, kernel_size=(3,3), activation="relu")(x) # input이 1개라서 그럼  64*10+ 64
x= Flatten()(x)

outputs =Dense(10, activation="softmax")(x) # 65*10

model = keras.Model(inputs=inputs, outputs=outputs) # input의 x가 들어가야 함 
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='acc')
model.fit(x_train,y_train, epochs = 5,batch_size = 128, validation_data = (x_val, y_val)) 
model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/5
# 352/352 [==============================] - 13s 36ms/step - loss: 0.6401 - acc: 0.7676 - val_loss: 0.4342 - val_acc: 0.8445
# Epoch 2/5
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4000 - acc: 0.8565 - val_loss: 0.3666 - val_acc: 0.8642
# Epoch 3/5
# 352/352 [==============================] - 13s 36ms/step - loss: 0.3441 - acc: 0.8770 - val_loss: 0.3246 - val_acc: 0.8823
# Epoch 4/5
# 352/352 [==============================] - 13s 36ms/step - loss: 0.3110 - acc: 0.8861 - val_loss: 0.3176 - val_acc: 0.8821
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3212 - acc: 0.8843
# [0.3211914896965027, 0.8842999935150146]

# %%
import tensorflow as tf

(train_images, train_labels),(test_images, test_labels) = fashion_mnist.load_data()
train_images=train_images.reshape(60000, 28,28,1) 
train_images=train_images/255.0
test_images=test_images.reshape(10000, 28,28,1) 
test_images=test_images/255.0     

x_val = train_images[:15000]
x_train = train_images[15000:]

y_val = train_labels[:15000]
y_train = train_labels[15000:]

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(x_train,y_train,epochs = 5,batch_size = 128, validation_data = (x_val, y_val)) 
model.evaluate(test_images, test_labels)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_27 (Conv2D)          (None, 26, 26, 64)        640
#
#  max_pooling2d_19 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_20 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 1600)              0
#
#  dense_13 (Dense)            (None, 128)               204928
#
#  dense_14 (Dense)            (None, 10)                1290
#
# ...
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 352/352 [==============================] - 21s 58ms/step - loss: 0.5784 - accuracy: 0.7922 - val_loss: 0.4073 - val_accuracy: 0.8549
# Epoch 2/5
# ...

# %%
import numpy as np
# mnist 패션데이터셋 불러오기
mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = mnist
X_train_full = X_train_full / 255.
X_test = X_test / 255.
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test[..., np.newaxis]


# simple convent 
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=3, padding="same",
                           activation="relu", kernel_initializer="he_normal"),
    tf.keras.layers.Conv2D(64, kernel_size=3, padding="same",
                           activation="relu", kernel_initializer="he_normal"),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam",
              metrics=["accuracy"])

model.fit(X_train, y_train ,epochs = 5,batch_size = 128, validation_data=(X_valid, y_valid))
model.evaluate(X_test, y_test)

#분류
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

#결과 일부 출력
n_rows = 8
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index][:,:,0], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show
()
# Out:
# Epoch 1/5
# 430/430 [==============================] - 55s 126ms/step - loss: 0.5190 - accuracy: 0.8220 - val_loss: 0.3126 - val_accuracy: 0.8816
# Epoch 2/5
# 430/430 [==============================] - 56s 130ms/step - loss: 0.3268 - accuracy: 0.8836 - val_loss: 0.2598 - val_accuracy: 0.9050
# Epoch 3/5
# 430/430 [==============================] - 54s 126ms/step - loss: 0.2738 - accuracy: 0.9016 - val_loss: 0.2394 - val_accuracy: 0.9148
# Epoch 4/5
# 430/430 [==============================] - 54s 126ms/step - loss: 0.2399 - accuracy: 0.9120 - val_loss: 0.2132 - val_accuracy: 0.9230
# Epoch 5/5
# ...
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2245 - accuracy: 0.9183
# ()

# %%
# 1. Fashion MNIST 데이터셋 불러오기
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images=train_images.reshape(60000, 28, 28, 1)
train_images = train_images[:50000]
train_labels = train_labels[:50000]
val_images = train_images[50000:]
val_labels = train_labels[50000:]

train_images=train_images / 255.0

test_images = test_images.reshape(10000, 28, 28, 1)

test_images=test_images/255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit
(train_images, train_labels,validation_data=(val_images,val_labels),epochs=5,batch_size=200)
test_loss = model.evaluate(test_images, test_labels)

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
numbers = np.random.permutation(train_images.shape[0])
indices = int(train_images.shape[0]*0.7)
indices

image_train =  train_images[:indices, :, :]
image_validation = train_images[indices:, :, :]

labels_train =  train_labels[:indices]
labels_validation =  train_labels[indices:]

image_train = image_train.astype("float32") / 255
image_validation = image_validation.astype("float32") / 255
test_images = test_images.astype("float32") / 255

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])

callbacks = [keras.callbacks.ModelCheckpoint("fashion_mnist.keras", 
                                             save_best_only = True)]
model.fit(image_train, labels_train, epochs=5, batch_size=64, 
          callbacks = callbacks,
          validation_data = (image_validation, labels_validation))


model = keras.models.load_model("fashion_mnist.keras")
model.evaluate(test_images, test_labels)



from sklearn.model_selection  import train_test_split

t_images, v_images, t_labels, v_labels= train_test_split(train_images, train_labels, test_size= 0.3)
# Out:
# Epoch 1/5
# 657/657 [==============================] - 14s 21ms/step - loss: 0.5696 - accuracy: 0.7887 - val_loss: 0.4456 - val_accuracy: 0.8317
# Epoch 2/5
# 657/657 [==============================] - 13s 20ms/step - loss: 0.3597 - accuracy: 0.8700 - val_loss: 0.3555 - val_accuracy: 0.8683
# Epoch 3/5
# 657/657 [==============================] - 13s 20ms/step - loss: 0.3065 - accuracy: 0.8900 - val_loss: 0.3626 - val_accuracy: 0.8696
# Epoch 4/5
# 657/657 [==============================] - 14s 21ms/step - loss: 0.2747 - accuracy: 0.9002 - val_loss: 0.3074 - val_accuracy: 0.8903
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3006 - accuracy: 0.8936

# %%
t_images, v_images, t_labels,  v_labels = train_test_split(train_images, train_labels, test_size=0.3)
# 이것은 자동으로 썩임 random sample 해야함 이유는 ... sample이 안썩이면 이상치가 나올 수도 ..

# %% [markdown]
# # CelebA 데이터셋 준비하기

# %% [markdown]
# ## gan

# %%
import gdown
url = "https://drive.google.com/uc?id=1lY922EZj1o3-q9gpTeVXNis2SU2LdPX8"
gdown.download(url, "celeba_gan.tar")

# %%
# !tar -xvf celeba_gan.tar

# %%
ls

# %%
from tensorflow import keras

dataset =keras.utils.image_dataset_from_directory(
    "celeba_gan",
     label_mode=None,
     image_size=(64,64),
    batch_size=32,
    smart_resize=True)

# %%
dataset =dataset.map(lambda x : x/255.)

# %%
from tensorflow.keras import layers
 # stride는 두칸띈다.
discriminator = keras.Sequential(
    [
        keras.Input(shape=(64, 64, 3)),
        layers.Conv2D(64, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid"),
    ],
    name="discriminator",
)

# %%
discriminator.summary()

# %%
latent_dim =128

generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        layers.Dense(8*8*128),
        layers.Reshape((8,8,128)),
        layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(256, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(512, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(3, kernel_size=5, padding="same", activation="sigmoid"),
    ],
    name="generator",
)

# %%
generator.summary() #파라미터가 10배 더 많음

# %%
import tensorflow as tf
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim))
        generated_images = self.generator(random_latent_vectors)  
        combined_images = tf.concat([generated_images, real_images], axis=0)
        labels = tf.concat(
            [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))],
            axis=0
        )
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        ################

        random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim))

        misleading_labels = tf.zeros((batch_size, 1))

        with tf.GradientTape() as tape:
            predictions = self.discriminator(
                self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(
            zip(grads, self.generator.trainable_weights))

        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {"d_loss": self.d_loss_metric.result(),
                "g_loss": self.g_loss_metric.result()}

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=128):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images *= 255
        generated_images.numpy()
        for i in range(self.num_img):
            img = keras.utils.array_to_img(generated_images[i])
            img.save(f"generated_img_{epoch:03d}_{i}.png")

# %%
epochs = 100
gan =GAN(discriminator=discriminator, generator= generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss_fn =keras.losses.BinaryCrossentropy(),
)

gan.fit(dataset, epochs=epochs, callbacks=[GANMonitor(num_img=10, latent_dim=latent_dim)])
